# %% [markdown]
# ## Tutorial and assignment 2.1

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model, model_selection

# %%
# Define a plotting function
def regr_plot(x, y_true, y_pred, title='', xlabel='', ylabel=''):
    plt.scatter(x, y_true,  color='black')
    plt.plot(x, y_pred, color='blue', linewidth=3)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.show()

# %%
X, y = datasets.load_diabetes(return_X_y=True)
print(X.shape)
print(X[0])
# Out:
# (442, 10)
# [ 0.03807591  0.05068012  0.06169621  0.02187239 -0.0442235  -0.03482076
#  -0.04340085 -0.00259226  0.01990749 -0.01764613]

# %%
#X1 = X[:, 2]
#X2 = X[:, np.newaxis, 2]

#print(X1.shape)
#print(X2.shape)
#X1 = X1.reshape((-1, 1))
#print(X1.shape)

X = X[:, 2]
X = X.reshape((-1,1))

# %% [markdown]
# Split the dataset into train and test sets

# %%
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.33)

# %%
model = linear_model.LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
#plt.scatter(X_test, y_test,  color='black')
#plt.plot(X_test, y_pred, color='blue', linewidth=3)
#plt.xlabel('Scaled BMIs')
#plt.ylabel('Disease Progression')
#plt.title('A Graph Plot Showing Diabetes Progression Against BMI')
#plt.show()
regr_plot(X_test, y_test, y_pred,
          title='A Graph Plot Showing Diabetes Progression Against BMI',
          xlabel='Scaled BMIs',
          ylabel='Disease Progression'
          )

# %% [markdown]
# Now do this for another part of the dataset.

# %%
X, y = datasets.load_diabetes(return_X_y=True)
X = X[:, np.newaxis, 9]
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.33)
model = linear_model.LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
plt.scatter(X_test, y_test,  color='black')
plt.plot(X_test, y_pred, color='blue', linewidth=3)
plt.xlabel('Scaled BMIs')
plt.ylabel('Disease Progression')
plt.title('A Graph Plot Showing Diabetes Progression Against BMI')
plt.show()

# %% [markdown]
# ### Assignment: Another dataset

# %%
X, Y = datasets.load_linnerud(return_X_y=True)
print(X.shape)
print(X[0])
print(Y.shape)
print(Y[0])
# Out:
# (20, 3)
# [  5. 162.  60.]
# (20, 3)
# [191.  36.  50.]

# %% [markdown]
# Both the waistline feature and the sit-ups' target is on the middle column of the data and target matrices respectively so hence column index 1:
#
# 1. Extract the middle column from X and Y respectively but keep 2 dimensions on the data array.
# 2. Create a new linear regression model and fit it to data and target.
# 3. Predict the target on the test data and compare with the true test targets by plotting

# %%
x_waist = X[:, np.newaxis, 1]
y_situps = Y[:, 1]
x_waist_train, x_waist_test, y_situps_train, y_situps_test = model_selection.train_test_split(x_waist,
                                                                                              y_situps,
                                                                                              test_size=0.33)
model = linear_model.LinearRegression()
model.fit(x_waist_train, y_situps_train)
y_situps_pred = model.predict(x_waist_test)

# %%
regr_plot(X_waist_test, y_situps_test, y_situps_pred, 'Waist measure vs # situps', 'Waist [cm]', '# situps')

# %%
# There are in total 2 more features and 2 more labels:
x_weight = X[:, np.newaxis, 0]
x_pulse = X[:, np.newaxis, 2]
y_chins = Y[:, 0]
y_jumps = Y[:, 2]

# %% [markdown]
# ##### With only one correlation explored (waist measure vs number of situps) there are 8 more to go:
# 1. weight vs chins
# 2. weight vs situps
# 3. weight vs jumps
# 4. waist vs chins
# 5. waist vs jumps
# 6. pulse vs chins
# 7. pulse vs situps
# 8. pulse vs jumps
